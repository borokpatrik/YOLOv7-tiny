# %% [markdown]
# Environment setup

# %%
import torch
print(torch.cuda.is_available())  # Should return True
# Out:
# True

# %% [markdown]
# Train model

# %%
# !python train.py --weights yolov7-tiny.pt --cfg cfg/training/yolov7-tiny.yaml --data data/localization.yaml --epochs 20 --batch-size 4 --img 320 --device cpu
# --name yolov7-tiny --project yolov7 --entity borok
#wandb.ai for later use
# Out:
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
#
# autoanchor: Analyzing anchors... anchors/target = 5.67, Best Possible Recall (BPR) = 1.0000
#                  all         324         324      0.0639       0.306      0.0424      0.0082
#                  all         324         324      0.0766       0.176      0.0492      0.0135
#                  all         324         324       0.203       0.281       0.148      0.0467
#                  all         324         324        0.38       0.235       0.186       0.069
#                  all         324         324        0.56        0.46       0.476       0.224
#                  all         324         324       0.782       0.543       0.625       0.327
#                  all         324         324       0.916       0.705       0.842       0.457
#                  all         324         324        0.88       0.836       0.883       0.549
# ...

# %% [markdown]
# Evaluate Model

# %%
# !python test.py --weights runs/train/exp16/weights/best.pt --data data/localization.yaml --img 320 --conf 0.25 --device 0
# Out:
# Namespace(weights=['runs/train/exp16/weights/best.pt'], data='data/localization.yaml', batch_size=32, img_size=320, conf_thres=0.25, iou_thres=0.65, task='val', device='0', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='exp', exist_ok=False, no_trace=False, v5_metric=False)
# Fusing layers...
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
#                  all         324         324        0.98       0.907       0.937       0.741
# Speed: 3.0/0.7/3.7 ms inference/NMS/total per 320x320 image at batch-size 32
# Results saved to runs\test\exp
# YOLOR  v0.1-128-ga207844 torch 1.12.0+cu113 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4095.875MB)
#
# ...

# %% [markdown]
# Test model

# %%
# !python detect.py --weights runs/train/exp16/weights/best.pt --source E:/Coding/ML/Localizations/dataset/test --img 320 --conf 0.25 --save-txt --device 0
# Out:
# Namespace(weights=['runs/train/exp16/weights/best.pt'], source='E:/Coding/ML/Localizations/dataset/test', img_size=320, conf_thres=0.25, iou_thres=0.45, device='0', view_img=False, save_txt=True, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# 1 cat, Done. (7.4ms) Inference, (3.0ms) NMS
#  The image with the result is saved in: runs\detect\exp7\00001324_010.jpg
# 1 cat, Done. (10.9ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\exp7\00001324_018.jpg
# 1 cat, Done. (10.0ms) Inference, (1.0ms) NMS
#  The image with the result is saved in: runs\detect\exp7\00001324_022.jpg
# 1 cat, Done. (8.0ms) Inference, (0.9ms) NMS
#  The image with the result is saved in: runs\detect\exp7\00001325_005.jpg
# ...
